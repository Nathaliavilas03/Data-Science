# %% [markdown]
# <a href="https://colab.research.google.com/github/Nathaliavilas03/Data-Science/blob/main/Introdu%C3%A7%C3%A3o_a_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
notas = pd.read_csv("https://raw.githubusercontent.com/afonsosr2/data-science-analise-exploratoria/refs/heads/main/Aula_1.2/ratings.csv")
notas
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
notas.shape
# Out:
# (100836, 4)

# %%
notas.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
notas.columns = ["usuarioId", "filmeId", "nota", "momento" ]
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas["nota"].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
notas["nota"].value_counts()
# Out:
# nota
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: count, dtype: int64

# %%
notas["nota"].mean()
# Out:
# 3.501556983616962

# %%
notas["nota"].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
mediana = notas["nota"].median()
media = notas["nota"].mean ()
print (f"Mediana é: {mediana}")
print (f"Media é -: {media}")
# Out:
# Mediana é: 3.5
# Media é -: 3.501556983616962

# %%
notas["nota"].describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: nota, dtype: float64

# %%
import seaborn as sns

sns.boxplot(notas["nota"])
# Out:
# <Axes: ylabel='nota'>

# %%
filmes = pd.read_csv("https://raw.githubusercontent.com/alura-cursos/data-science-analise-exploratoria/refs/heads/main/Aula_2.1/movies.csv")
filmes.columns = ["filmeId", "titulo", "generos"]
filmes.head()
# Out:
#    filmeId                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas.query("filmeId==1")["nota"].mean()
# Out:
# 3.9209302325581397

# %%
notas.query("filmeId==2")["nota"].mean()
# Out:
# 3.4318181818181817

# %%
medias_por_filme = notas.groupby("filmeId")["nota"].mean()
medias_por_filme.head()
# Out:
# filmeId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: nota, dtype: float64

# %%
medias_por_filme.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.boxplot(medias_por_filme)
# Out:
# <Axes: ylabel='nota'>

# %%
medias_por_filme.describe()
# Out:
# count    9724.000000
# mean        3.262448
# std         0.869874
# min         0.500000
# 25%         2.800000
# 50%         3.416667
# 75%         3.911765
# max         5.000000
# Name: nota, dtype: float64

# %%
import matplotlib.pyplot as plt

sns.displot(medias_por_filme, kde=True)
plt.title("Histograma das medias dos filmes")
# Out:
# Text(0.5, 1.0, 'Histograma das medias dos filmes')

# %%
tmdb = pd.read_csv("https://raw.githubusercontent.com/alura-cursos/data-science-analise-exploratoria/main/Aula_0/tmdb_5000_movies.csv")
tmdb.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
sns.displot (tmdb["revenue"])
plt.title("Distribuição da receita dos filmes")
plt.show()

# %%
import matplotlib.pyplot as plt

sns.displot(tmdb["budget"])
plt.title("Distribuição do orçamento dos filmes")
plt.show()

# %%
com_faturamento = tmdb.query("revenue > 500")
sns.displot(com_faturamento["revenue"])

# %%
tmdb["original_language"].unique()
# Out:
# array(['en', 'ja', 'fr', 'zh', 'es', 'de', 'hi', 'ru', 'ko', 'te', 'cn',
#        'it', 'nl', 'ta', 'sv', 'th', 'da', 'xx', 'hu', 'cs', 'pt', 'is',
#        'tr', 'nb', 'af', 'pl', 'he', 'ar', 'vi', 'ky', 'id', 'ro', 'fa',
#        'no', 'sl', 'ps', 'el'], dtype=object)

# %%
contagem_de_linguas = tmdb["original_language"].value_counts().to_frame().reset_index()
contagem_de_linguas.columns = ["original_language", "total"]
contagem_de_linguas.head()
# Out:
#   original_language  total
# 0                en   4505
# 1                fr     70
# 2                es     32
# 3                zh     27
# 4                de     27

# %%
contagem_de_linguas.plot()
# Out:
# <Axes: >

# %%
sns.barplot(data=contagem_de_linguas, x="original_language",y="total")
# Out:
# <Axes: xlabel='original_language', ylabel='total'>

# %%
sns.countplot(data=tmdb, x="original_language")
# Out:
# <Axes: xlabel='original_language', ylabel='count'>

# %%
contagem_de_linguas.plot(kind="pie", y="total", labels=contagem_de_linguas["original_language"])
# Out:
# <Axes: ylabel='total'>

# %%
total_por_lingua = tmdb["original_language"].value_counts()
total_geral = total_por_lingua.sum()
total_de_ingles = total_por_lingua.loc["en"]
total_do_resto = total_geral - total_de_ingles
print(total_geral, total_de_ingles, total_do_resto)
# Out:
# 4803 4505 298

# %%
dados = {
    "lingua": ["ingles", "outros"],
    "total": [total_de_ingles, total_do_resto]
}
dados = pd.DataFrame(dados)
dados
# Out:
#    lingua  total
# 0  ingles   4505
# 1  outros    298

# %%
sns.barplot(data=dados, x="lingua", y="total")
# Out:
# <Axes: xlabel='lingua', ylabel='total'>

# %%
dados.plot(kind="pie", y="total", labels=dados["lingua"])
# Out:
# <Axes: ylabel='total'>

# %%
total_de_outros_filmes_por_lingua = tmdb.query("original_language != 'en'")["original_language"].value_counts()
total_de_outros_filmes_por_lingua.head()
# Out:
# original_language
# fr    70
# es    32
# zh    27
# de    27
# hi    19
# Name: count, dtype: int64

# %%
sns.countplot(data=tmdb.query("original_language != 'en'"), x="original_language")
# Out:
# <Axes: xlabel='original_language', ylabel='count'>

# %%
import pandas as pd
import seaborn as sns

# Importando a base de dados
tmdb = pd.read_csv("https://raw.githubusercontent.com/alura-cursos/data-science-analise-exploratoria/main/Aula_0/tmdb_5000_movies.csv")

# Filtrando os dados para as colunas desejadas
dados = tmdb[["title", "original_language", "budget", "revenue"]]
linguas = ["fr", "es", "de"]

# Mantendo dados com valores de receita e orçamento válidos e nas línguas desejadas (fr, es, de)
fr_es_de_com_revenue_e_budget = dados.query("revenue > 0 and budget > 0 and original_language == @linguas")

# Construindo o gráfico de dispersão mais a reta de regressão linear para cada caso
sns.lmplot(data=fr_es_de_com_revenue_e_budget, x="budget", y="revenue", col="original_language",
           hue="original_language", ci=None, height=4, scatter_kws={"s": 30, "alpha": 0.5})

# %%
sns.countplot(data=tmdb.query("original_language != 'en'"),
              order=total_de_outros_filmes_por_lingua.index,
              hue="original_language",
              x="original_language")
# Out:
# <Axes: xlabel='original_language', ylabel='count'>

# %%
tmdb.query("original_language != 'en'")["original_language"].value_counts(normalize=True)
# Out:
# original_language
# fr    0.234899
# es    0.107383
# zh    0.090604
# de    0.090604
# hi    0.063758
# ja    0.053691
# it    0.046980
# cn    0.040268
# ko    0.036913
# ru    0.036913
# pt    0.030201
# da    0.023490
# sv    0.016779
# fa    0.013423
# nl    0.013423
# he    0.010067
# th    0.010067
# ro    0.006711
# id    0.006711
# ar    0.006711
# cs    0.006711
# ta    0.006711
# tr    0.003356
# nb    0.003356
# af    0.003356
# pl    0.003356
# is    0.003356
# hu    0.003356
# vi    0.003356
# ky    0.003356
# xx    0.003356
# te    0.003356
# no    0.003356
# sl    0.003356
# ps    0.003356
# el    0.003356
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(16,8))
sns.countplot(data=tmdb.query("original_language != 'en'"),
              order=total_de_outros_filmes_por_lingua.index,
              palette="mako",
              hue="original_language",
              stat="percent",
              hue_order=total_de_outros_filmes_por_lingua.index,
              x="original_language")
# Out:
# <Axes: xlabel='original_language', ylabel='percent'>

# %%
#extraia as notas dos dois filmes em variaveis disintas

nota_do_toy_story = notas.query("filmeId==1")["nota"]
nota_do_jumanji = notas.query("filmeId==2")["nota"]

media_do_toy_story = nota_do_toy_story.mean()
media_do_jumanji = nota_do_jumanji.mean()

print(media_do_toy_story, media_do_jumanji)
# Out:
# 3.9209302325581397 3.4318181818181817

# %%
# prompt: mesmo mas com a mediana

mediana_do_toy_story = nota_do_toy_story.median()
mediana_do_jumanji = nota_do_jumanji.median()

print(mediana_do_toy_story, mediana_do_jumanji)
# Out:
# 4.0 3.5

# %%
import numpy as np

filme1 = [2.5]*10 +[3.5]*10
filme2 = [5]*10 +[1]*10

# %%
# prompt: imprima a media e mediana do filme 1 e filme 2

import numpy as np

media_filme1 = np.mean(filme1)
mediana_filme1 = np.median(filme1)

media_filme2 = np.mean(filme2)
mediana_filme2 = np.median(filme2)

print(f"Média do Filme 1: {media_filme1}")
print(f"Mediana do Filme 1: {mediana_filme1}")

print(f"Média do Filme 2: {media_filme2}")
print(f"Mediana do Filme 2: {mediana_filme2}")
# Out:
# Média do Filme 1: 3.0
# Mediana do Filme 1: 3.0
# Média do Filme 2: 3.0
# Mediana do Filme 2: 3.0

# %%
plt.hist(filme1)
plt.hist(filme2)
# Out:
# (array([10.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0., 10.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot([filme1,filme2])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f4284117fd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f4284140520>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f4284117d30>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f4284140a60>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f4284140d00>,
# ...
#  'means': []}

# %%
filme0 = [3]*20
np.mean(filme0)
# Out:
# 3.0

# %%
np.std(filme0), np.std(filme1), np.std(filme2)
# Out:
# (0.0, 0.5, 2.0)

# %%
nota_do_toy_story = notas.query("filmeId==1")["nota"]
nota_do_jumanji = notas.query("filmeId==2")["nota"]

plt.boxplot([nota_do_toy_story,nota_do_jumanji])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f42841c90c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f42841c9600>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f42841c8e20>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f42841c9b40>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f42841c9de0>,
# ...
#  'means': []}

# %%
sns.boxplot(data=notas.query("filmeId in [1,2]"),
            x="filmeId",
            y="nota")
# Out:
# <Axes: xlabel='filmeId', ylabel='nota'>

# %%
# prompt: mesmo grafico mas colorido

sns.boxplot(data=notas.query("filmeId in [1,2]"),
            x="filmeId",
            y="nota", palette="Set2")
# Out:
# <ipython-input-162-ac7414683ea2>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=notas.query("filmeId in [1,2]"),
# <Axes: xlabel='filmeId', ylabel='nota'>

# %%
notas.groupby("filmeId").count()
# Out:
#          usuarioId  nota  momento
# filmeId
# 1              215   215      215
# 2              110   110      110
# 3               52    52       52
# 4                7     7        7
# 5               49    49       49
# ...            ...   ...      ...
# 193581           1     1        1
# 193583           1     1        1
# 193585           1     1        1
# 193587           1     1        1
# 193609           1     1        1
#
# [9724 rows x 3 columns]

# %%
notas["filmeId"].value_counts().tail()
# Out:
# filmeId
# 86279     1
# 86922     1
# 5962      1
# 87660     1
# 163981    1
# Name: count, dtype: int64

# %%
notas.groupby("filmeId").count().query("nota ==1 ")
# Out:
#          usuarioId  nota  momento
# filmeId
# 49               1     1        1
# 55               1     1        1
# 77               1     1        1
# 83               1     1        1
# 96               1     1        1
# ...            ...   ...      ...
# 193581           1     1        1
# 193583           1     1        1
# 193585           1     1        1
# 193587           1     1        1
# 193609           1     1        1
#
# [3446 rows x 3 columns]
